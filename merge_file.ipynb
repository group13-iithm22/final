# %%
from linesplitter import linesplitter
linesplitter("song1.txt")
linesplitter("song2.txt")
linesplitter("song3.txt")
linesplitter("song4.txt")
linesplitter("song5.txt")
linesplitter("song6.txt")
linesplitter("song7.txt")
linesplitter("song8.txt")
linesplitter("song9.txt")
linesplitter("song10.txt")
# Out:
# song1-1	In the year of 2525
# song1-2	If man is still alive
# song1-3	If woman can survive
# song1-4	They may find
# song1-5	In the year of 3535
# song1-6	Can't tell the truth, can't tell no lie
# song1-7	Everything you think, do and say
# song1-8	Is in the pill you took today
# song1-9	In the year of 4545
# song1-10	Won't need no teeth ,won't need your eyes
# song1-11	Won't find a thing to do
# song1-12	Nobody's gonna look at you
# song1-13	In the year of 5555
# song1-14	Your arms are hanging limp at your side
# song1-15	Your legs have nothing to do
# song1-16	Some machines doin' that for you
# song1-17	In the year of 6565
# song1-18	Won't need no husband, won't need no wife
# song1-19	You'll pick your sons, pick your daughters too
# song1-20	From the bottom of a long glass tube wouwo
# song1-21	In the year of 7510
# song1-22	If god is commin' he should make it by then
# song1-23	Maybe he'll look around and say:
# song1-24	"Now it's time for the judgement day!"
# ...

# %%
all_songs = ["song1.txt", "song2.txt", "song3.txt", "song4.txt", "song5.txt", "song6.txt", "song7.txt", "song8.txt", "song9.txt", "song10.txt"]

# %%
import pandas as pd

files = [all_songs]
 
writer = pd.ExcelWriter('merged_file.xlsx', engine='xlsxwriter')
 
for i, file in enumerate(files):
    df = pd.read_csv(file, sep=",")
     
    df.to_excel(writer, sheet_name=str(sheet_names[i]))
 
writer.save()
